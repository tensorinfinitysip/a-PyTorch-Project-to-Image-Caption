# %%
from inference import *
img_path = 'datasets/Flicker8k_Dataset/42637987_866635edf6.jpg'
image = Image.open(img_path).convert("RGB")
caps, cap_scores, alphas = get_image_caption(image)

# %%
visualization_att(image, caps, alphas)

# %%
img_path = 'datasets/Flicker8k_Dataset/3578914491_36019ba703.jpg'
image = Image.open(img_path).convert("RGB")
caps, cap_scores, alphas = get_image_caption(image)
visualization_att(image, caps, alphas)

# %%
a = torch.randn(1, 2, 2)

# %%
a
# Out:
# tensor([[[ 1.5151,  0.6847],
#          [ 1.4409, -0.3029]]])

# %%
F.adaptive_avg_pool2d(a, (8, 8))
# Out:
# tensor([[[ 1.5151,  1.5151,  1.5151,  1.5151,  0.6847,  0.6847,  0.6847,
#            0.6847],
#          [ 1.5151,  1.5151,  1.5151,  1.5151,  0.6847,  0.6847,  0.6847,
#            0.6847],
#          [ 1.5151,  1.5151,  1.5151,  1.5151,  0.6847,  0.6847,  0.6847,
#            0.6847],
#          [ 1.5151,  1.5151,  1.5151,  1.5151,  0.6847,  0.6847,  0.6847,
#            0.6847],
#          [ 1.4409,  1.4409,  1.4409,  1.4409, -0.3029, -0.3029, -0.3029,
#           -0.3029],
#          [ 1.4409,  1.4409,  1.4409,  1.4409, -0.3029, -0.3029, -0.3029,
#           -0.3029],
#          [ 1.4409,  1.4409,  1.4409,  1.4409, -0.3029, -0.3029, -0.3029,
#           -0.3029],
#          [ 1.4409,  1.4409,  1.4409,  1.4409, -0.3029, -0.3029, -0.3029,
#           -0.3029]]])
